# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
from pathlib import Path
import random

# %% [markdown]
# # Find diff
# A comparison of the two datasets we found that appear to be similar

# %%
file = '../eye_positions.csv'

# %% [markdown]
# ### Test Control subject 111GM3

# %%
df = pd.read_csv(file)
df.head()
# Out:
#            time     fix_x     fix_y
# 0  1.780416e+09  0.599734  0.599802
# 1  1.780416e+09  0.607993  0.644269
# 2  1.780416e+09  0.587372  0.596014
# 3  1.780416e+09  0.607993  0.616848
# 4  1.780416e+09  0.653061  0.647826

# %%
plt.plot(df["fix_x"], df["fix_y"])

# %%
plt.plot(df["gaze_x_left"], df["gaze_y_left"])
plt.plot(df["gaze_x_right"], df["gaze_y_right"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.6/envs/dyslexia/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'gaze_x_left'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ...
