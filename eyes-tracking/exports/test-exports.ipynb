# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
from pathlib import Path
import random

# %% [markdown]
# # Find diff
# A comparison of the two datasets we found that appear to be similar

# %%
file = 'gaze_log (3).csv'

# %% [markdown]
# ### Test Control subject 111GM3

# %%
df = pd.read_csv(file)
df.head()
# Out:
#            time  fix_x  fix_y  gaze_x_left  gaze_y_left  gaze_x_right  \
# 0  1.780490e+09    395    568          429          656           398
# 1  1.780490e+09    395    571          421          689           353
# 2  1.780490e+09    399    563          476          594           344
# 3  1.780490e+09    404    573          504          686           309
# 4  1.780490e+09    408    581          486          679           361
#
#    gaze_y_right
# 0           488
# 1           554
# 2           471
# 3           580
# 4           528

# %%
plt.plot(df["fix_x"], df["fix_y"])

# %%
plt.scatter(df["gaze_x_left"], df["gaze_y_left"])
plt.scatter(df["gaze_x_right"], df["gaze_y_right"])
