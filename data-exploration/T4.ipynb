# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # T4 Meaningful Text Data Exploration

# %% [markdown]
# ## Checking Individual data

# %%
ind_1003_fixations = pd.read_csv('/home/yoannl/code/drealKn/DyslexIA/data/data/Subject_1003_T4_Meaningful_Text_fixations.csv')
ind_1003_metrics = pd.read_csv('/home/yoannl/code/drealKn/DyslexIA/data/data/Subject_1003_T4_Meaningful_Text_metrics.csv')
ind_1003_raw = pd.read_csv('/home/yoannl/code/drealKn/DyslexIA/data/data/Subject_1003_T4_Meaningful_Text_raw.csv')
ind_1003_sacc = pd.read_csv('/home/yoannl/code/drealKn/DyslexIA/data/data/Subject_1003_T4_Meaningful_Text_saccades.csv')

# %%
ind_1996_fixations = pd.read_csv('/home/yoannl/code/drealKn/DyslexIA/data/data/Subject_1996_T4_Meaningful_Text_fixations.csv')
ind_1996_metrics = pd.read_csv('/home/yoannl/code/drealKn/DyslexIA/data/data/Subject_1996_T4_Meaningful_Text_metrics.csv')
ind_1996_raw = pd.read_csv('/home/yoannl/code/drealKn/DyslexIA/data/data/Subject_1996_T4_Meaningful_Text_raw.csv')
ind_1996_sacc = pd.read_csv('/home/yoannl/code/drealKn/DyslexIA/data/data/Subject_1996_T4_Meaningful_Text_saccades.csv')

# %% [markdown]
# ### Raw data

# %%
ind_1003_raw.head()
# Out:
#         time  gaze_x_left  gaze_y_left  gaze_x_right  gaze_y_right  \
# 0  824350933       146.35       133.98        154.82        138.67
# 1  824354929       147.32       134.90        154.42        140.37
# 2  824358926       149.22       135.17        153.96        140.50
# 3  824362922       151.37       137.59        151.24        141.70
# 4  824366918       152.25       140.08        146.30        143.71
#
#    pupil_left  pupil_right           stimfile  subject_id
# 0        4.32         4.05  s7_stimuli_t4.jpg        1003
# 1        4.32         4.05  s7_stimuli_t4.jpg        1003
# 2        4.32         4.05  s7_stimuli_t4.jpg        1003
# 3        4.32         4.05  s7_stimuli_t4.jpg        1003
# 4        4.31         4.05  s7_stimuli_t4.jpg        1003

# %%
ind_1003_raw.describe()
# Out:
#                time   gaze_x_left   gaze_y_left  gaze_x_right  gaze_y_right  \
# count  1.533200e+04  15332.000000  15332.000000  15332.000000  15332.000000
# mean   8.550102e+08    858.510429    497.194800    843.826451    499.501927
# std    1.770290e+07    351.973515    194.736722    352.689365    193.710667
# min    8.243509e+08      0.000000      0.000000      0.000000      0.000000
# 25%    8.396806e+08    527.760000    351.505000    513.985000    351.297500
# 50%    8.550103e+08    896.835000    491.480000    884.590000    493.805000
# 75%    8.703398e+08   1153.572500    665.247500   1147.945000    671.052500
# max    8.856695e+08   1549.930000   1055.780000   1537.770000   1093.430000
#
#          pupil_left   pupil_right  subject_id
# count  15332.000000  15332.000000     15332.0
# mean       4.006343      3.772063      1003.0
# std        0.277328      0.256953         0.0
# min        0.000000      0.000000      1003.0
# 25%        3.860000      3.660000      1003.0
# ...

# %% [markdown]
# ### Scatter non-dyslexic

# %%
X_left = ind_1003_raw['gaze_x_left']
Y_left = ind_1003_raw['gaze_y_left']
X_right = ind_1003_raw['gaze_x_right']
Y_right = ind_1003_raw['gaze_y_right']


plt.scatter(X_left, Y_left)
plt.scatter(X_right, Y_right)

# %% [markdown]
# ### Scatter dyslexic

# %%
X_left = ind_1996_raw['gaze_x_left']
Y_left = ind_1996_raw['gaze_y_left']
X_right = ind_1996_raw['gaze_x_right']
Y_right = ind_1996_raw['gaze_y_right']


plt.scatter(X_left, Y_left)
plt.scatter(X_right, Y_right)

# %% [markdown]
# ### Gaze over time non-dyslexic

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

ax1.plot(ind_1003_raw['time'], ind_1003_raw['gaze_x_left'])
ax1.legend(['gaze_x_left'])

ax2.plot(ind_1003_raw['time'], ind_1003_raw['gaze_y_left'])
ax2.legend(['gaze_y_left'])

# %% [markdown]
# ### Gaze over time dyslexic

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

ax1.plot(ind_1996_raw['time'], ind_1996_raw['gaze_x_left'])
ax1.legend(['gaze_x_left'])

ax2.plot(ind_1996_raw['time'], ind_1996_raw['gaze_y_left'])
ax2.legend(['gaze_y_left'])

# %% [markdown]
# ### Pupil non-dyslexic

# %%
pupil_left = ind_1003_raw['pupil_left']
pupil_right = ind_1003_raw['pupil_right']
durations = ind_1003_raw['time']

plt.scatter(pupil_left, durations)
plt.scatter(pupil_right, durations)

# %% [markdown]
# ### Pupil dyslexic

# %%
pupil_left = ind_1996_raw['pupil_left']
pupil_right = ind_1996_raw['pupil_right']
durations = ind_1996_raw['time']

plt.scatter(pupil_left, durations)
plt.scatter(pupil_right, durations)

# %% [markdown]
# ## Metrics

# %%
ind_1003_metrics.head()
# Out:
#     sid           stimfile eye_used  trialid  n_fix_trial  sum_fix_dur_trial  \
# 0  1003  s7_stimuli_t4.jpg        b      158          141          57011.064
# 1  1003  s7_stimuli_t4.jpg        b      158          141          57011.064
# 2  1003  s7_stimuli_t4.jpg        b      158          141          57011.064
# 3  1003  s7_stimuli_t4.jpg        b      158          141          57011.064
# 4  1003  s7_stimuli_t4.jpg        b      158          141          57011.064
#
#    dwell_time_trial  mean_fix_dur_trial  n_sacc_trial  sum_sacc_dur_trial  \
# 0          61314.61          404.333787           140            4867.475
# 1          61314.61          404.333787           140            4867.475
# 2          61314.61          404.333787           140            4867.475
# 3          61314.61          404.333787           140            4867.475
# 4          61314.61          404.333787           140            4867.475
#
# ...

# %%
ind_1003_metrics.dtypes
# Out:
# sid                                    int64
# stimfile                              object
# eye_used                              object
# trialid                                int64
# n_fix_trial                            int64
# sum_fix_dur_trial                    float64
# dwell_time_trial                     float64
# mean_fix_dur_trial                   float64
# n_sacc_trial                           int64
# sum_sacc_dur_trial                   float64
# mean_sacc_dur_trial                  float64
# mean_sacc_ampl_trial                 float64
# ratio_progress_regress_trial         float64
# n_between_line_regress_trial           int64
# n_within_line_regress_trial            int64
# n_regress_trial                        int64
# n_progress_trial                       int64
# n_transit_trial                        int64
# aoi                                   object
# aoi_kind                              object
# content                               object
# ...

# %%
ind_1003_metrics.iloc[:, 17:]
# Out:
#      n_transit_trial                aoi aoi_kind    content  dwell_time_aoi  \
# 0                108           line_001     line        NaN        7111.376
# 1                108  line_001-part_001  subline       Malý         295.943
# 2                108  line_001-part_002  subline      Pepík         332.069
# 3                108  line_001-part_003  subline     raději         631.892
# 4                108  line_001-part_004  subline       četl         471.944
# ..               ...                ...      ...        ...             ...
# 102              108  line_007-part_011  subline         si         255.963
# 103              108  line_007-part_012  subline  uschovala        2215.849
# 104              108  line_007-part_013  subline         do           0.000
# 105              108  line_007-part_014  subline      tajné         643.920
# 106              108  line_007-part_015  subline    skrýše.         395.925
#
# ...

# %%
ind_1003_metrics.describe()
# Out:
#           sid  trialid  n_fix_trial  sum_fix_dur_trial  dwell_time_trial  \
# count   107.0    107.0        107.0       1.070000e+02      1.070000e+02
# mean   1003.0    158.0        141.0       5.701106e+04      6.131461e+04
# std       0.0      0.0          0.0       7.310198e-12      1.462040e-11
# min    1003.0    158.0        141.0       5.701106e+04      6.131461e+04
# 25%    1003.0    158.0        141.0       5.701106e+04      6.131461e+04
# 50%    1003.0    158.0        141.0       5.701106e+04      6.131461e+04
# 75%    1003.0    158.0        141.0       5.701106e+04      6.131461e+04
# max    1003.0    158.0        141.0       5.701106e+04      6.131461e+04
#
#        mean_fix_dur_trial  n_sacc_trial  sum_sacc_dur_trial  \
# count          107.000000         107.0             107.000
# mean           404.333787         140.0            4867.475
# std              0.000000           0.0               0.000
# min            404.333787         140.0            4867.475
# ...

# %%
ind_1996_metrics.describe()
# Out:
#           sid  trialid  n_fix_trial  sum_fix_dur_trial  dwell_time_trial  \
# count   107.0    107.0        107.0            107.000      1.070000e+02
# mean   1996.0    158.0        326.0         128541.024      1.384076e+05
# std       0.0      0.0          0.0              0.000      2.924079e-11
# min    1996.0    158.0        326.0         128541.024      1.384076e+05
# 25%    1996.0    158.0        326.0         128541.024      1.384076e+05
# 50%    1996.0    158.0        326.0         128541.024      1.384076e+05
# 75%    1996.0    158.0        326.0         128541.024      1.384076e+05
# max    1996.0    158.0        326.0         128541.024      1.384076e+05
#
#        mean_fix_dur_trial  n_sacc_trial  sum_sacc_dur_trial  \
# count        1.070000e+02         107.0             107.000
# mean         3.942976e+02         325.0           11170.526
# std          1.142218e-13           0.0               0.000
# min          3.942976e+02         325.0           11170.526
# ...

# %%
fig, ax = plt.subplots(figsize=(15,15))
sns.heatmap(ind_1003_metrics.select_dtypes(include=[np.number]).corr(), annot=True, cmap='coolwarm', ax=ax)
# Out:
# <Axes: >

# %% [markdown]
# ## Fixations

# %%
ind_1003_fixations.head()
# Out:
#    id                task   sid eye           stimfile  trialid    start_ms  \
# 0   0  T4_Meaningful_Text  1003   b  s7_stimuli_t4.jpg      158  824350.933
# 1   1  T4_Meaningful_Text  1003   b  s7_stimuli_t4.jpg      158  824558.854
# 2   2  T4_Meaningful_Text  1003   b  s7_stimuli_t4.jpg      158  824746.897
# 3   3  T4_Meaningful_Text  1003   b  s7_stimuli_t4.jpg      158  825066.845
# 4   4  T4_Meaningful_Text  1003   b  s7_stimuli_t4.jpg      158  825250.880
#
#        end_ms  duration_ms     fix_x  fix_y  orig_fix_x  orig_fix_y    disp_x  \
# 0  824522.859      175.926  150.5075  198.5    150.5075    140.0650  0.761245
# 1  824722.888      168.035  371.6975  198.5    371.6975    193.8175  0.693621
# 2  825042.840      299.944  305.8250  198.5    305.8250    202.7100  0.926265
# 3  825234.880      172.035  381.1700  198.5    381.1700    193.0650  1.025816
# 4  825882.772      635.891  458.4800  198.5    458.4800    186.7600  0.940948
#
# ...

# %% [markdown]
# ### Non-dyslexic fixations

# %%
X_fix = ind_1003_fixations['fix_x']
Y_fix = ind_1003_fixations['fix_y']
X_orig = ind_1003_fixations['orig_fix_x']
Y_orig = ind_1003_fixations['orig_fix_y']

plt.scatter(X_fix, Y_fix)
plt.scatter(X_orig, Y_orig)

# %% [markdown]
# ### Dyslexic fixations

# %%
X_fix = ind_1996_fixations['fix_x']
Y_fix = ind_1996_fixations['fix_y']
X_orig = ind_1996_fixations['orig_fix_x']
Y_orig = ind_1996_fixations['orig_fix_y']

plt.scatter(X_fix, Y_fix)
plt.scatter(X_orig, Y_orig)

# %% [markdown]
# ## Saccades

# %%
ind_1003_sacc.head()
# Out:
#    id                task   sid eye           stimfile  trialid    start_ms  \
# 0   0  T4_Meaningful_Text  1003   b  s7_stimuli_t4.jpg      158  824522.859
# 1   1  T4_Meaningful_Text  1003   b  s7_stimuli_t4.jpg      158  824722.888
# 2   2  T4_Meaningful_Text  1003   b  s7_stimuli_t4.jpg      158  825042.840
# 3   3  T4_Meaningful_Text  1003   b  s7_stimuli_t4.jpg      158  825234.880
# 4   4  T4_Meaningful_Text  1003   b  s7_stimuli_t4.jpg      158  825882.772
#
#        end_ms  duration_ms  start_x  ...   ampl_x  ampl_y   avg_vel_x  \
# 0  824558.854       35.995  135.405  ...  213.695  20.745  156.184823
# 1  824746.897       24.009  363.115  ...   40.730   1.690   46.534634
# 2  825066.845       24.005  291.920  ...   56.160   0.060   61.545020
# 3  825250.880       16.000  377.545  ...   53.010   3.875   87.159388
# 4  825926.762       43.990  454.595  ...   65.300   9.295   42.112954
#
#    avg_vel_y  peak_vel_x  peak_vel_y    end_x     avg_vel    peak_vel  \
# ...

# %% [markdown]
# ### Non-dyslexic saccades

# %%
X_start = ind_1003_sacc['start_x']
Y_start = ind_1003_sacc['start_y']
X_end = ind_1003_sacc['end_x']
Y_end = ind_1003_sacc['end_y']

plt.scatter(X_start, Y_start)
plt.scatter(X_end, Y_end)

# %% [markdown]
# ### Dyslexic saccades

# %%
X_start = ind_1996_sacc['start_x']
Y_start = ind_1996_sacc['start_y']
X_end = ind_1996_sacc['end_x']
Y_end = ind_1996_sacc['end_y']

plt.scatter(X_start, Y_start)
plt.scatter(X_end, Y_end)

# %%
plt.hist(ind_1003_sacc['ampl'])
# Out:
# (array([125.,   8.,   1.,   0.,   0.,   0.,   0.,   0.,   2.,   4.]),
#  array([   7.85759823,  111.8513071 ,  215.84501596,  319.83872482,
#          423.83243369,  527.82614255,  631.81985141,  735.81356028,
#          839.80726914,  943.800978  , 1047.79468687]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(ind_1003_sacc['avg_vel'])
# Out:
# (array([78., 46.,  9.,  0.,  0.,  2.,  2.,  1.,  1.,  1.]),
#  array([ 14.1182471 ,  62.52861132, 110.93897553, 159.34933975,
#         207.75970396, 256.17006818, 304.58043239, 352.99079661,
#         401.40116082, 449.81152504, 498.22188925]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(ind_1003_sacc['peak_vel'])
# Out:
# (array([139.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   1.]),
#  array([  23.2008821 ,  973.77781336, 1924.35474463, 2874.93167589,
#         3825.50860716, 4776.08553842, 5726.66246969, 6677.23940095,
#         7627.81633222, 8578.39326348, 9528.97019475]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Conclusions

# %% [markdown]
# - Raw, fixations and saccades are time series
# - Metrics is external data linked to lines of text and individual words (aoi)
# - Raw and saccades are positional data
# - Fixations are positional and also linked to lines of text and individual words (aoi)
